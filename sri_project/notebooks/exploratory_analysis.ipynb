# %%
pip install matplotlib seaborn pandas
# Out:
# Requirement already satisfied: matplotlib in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: pandas in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sebpe\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  Definir ruta del dataset limpio
data_path = "../data/final/sri_autos_final.csv"

# %%
# Cargar el dataset
df = pd.read_csv(data_path, delimiter=';', encoding="latin-1", low_memory=False)

# %%
# Mostrar información general del dataset
print("Información del dataset:")
print(df.info())
# Out:
# 📌 Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12222 entries, 0 to 12221
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   marca             12222 non-null  object
#  1   modelo            12222 non-null  object
#  2   pais              9202 non-null   object
#  3   year_modelo       12222 non-null  int64
#  4   clase             12222 non-null  object
#  5   sub_clase         12222 non-null  object
#  6   avaluo            12222 non-null  float64
#  7   cilindraje        12222 non-null  int64
#  8   tipo_combustible  12222 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 859.5+ KB
# None

# %%
# Descripción estadística de las variables numéricas
print("\n Estadísticas descriptivas:")
print(df.describe())
# Out:
# 📌 Estadísticas descriptivas:
#         year_modelo         avaluo    cilindraje
# count  12222.000000   12222.000000  12222.000000
# mean    2020.174440   32927.326640   1952.301669
# std        3.126314   19425.702008    861.615686
# min     1960.000000     275.000000      0.000000
# 25%     2018.000000   19990.000000   1498.000000
# 50%     2020.000000   27990.000000   1968.000000
# 75%     2023.000000   39990.000000   2400.000000
# max     2025.000000  100000.000000  29999.000000

# %%
#  Histograma de "avaluo"
plt.figure(figsize=(10, 5))
sns.histplot(df["avaluo"], bins=30, kde=True, color="blue")
plt.xlabel("Avaluo ($)")
plt.ylabel("Cantidad de Autos")
plt.title("Distribución de Avalúos de Vehículos en Ecuador")
plt.show()

# %%
#  Histograma de "cilindraje"
plt.figure(figsize=(10, 5))
sns.histplot(df["cilindraje"], bins=30, kde=True, color="red")
plt.xlabel("Cilindraje")
plt.ylabel("Cantidad de Autos")
plt.title("Distribución del Cilindraje de Vehículos")
plt.show()

# %%
# Relación entre "avaluo" y "year_modelo"
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df["year_modelo"], y=df["avaluo"], alpha=0.5)
plt.xlabel("Año del Modelo")
plt.ylabel("Avaluo ($)")
plt.title("Relación entre Año del Modelo y Avalúo")
plt.show()

# %%
# Relación entre "cilindraje" y "avaluo"
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df["cilindraje"], y=df["avaluo"], alpha=0.5)
plt.xlabel("Cilindraje")
plt.ylabel("Avaluo ($)")
plt.title("Relación entre Cilindraje y Avalúo")
plt.show()
